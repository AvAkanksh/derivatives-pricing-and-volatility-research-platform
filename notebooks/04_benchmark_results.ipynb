# %% [markdown]
# # Notebook 04: Pricing Engine Performance Benchmarks
# This notebook executes performance benchmarks for both the Binomial Tree and Crank-Nicolson PDE option pricing engines.
# It records and displays the pre-compilation (warmup) compilation latency vs. steady-state execution latencies.

# %%
import sys
sys.path.append('../src')
from dpp.benchmark.bench_pricers import run_performance_benchmarks

print("Running Performance Timing Harness...")
perf = run_performance_benchmarks()
print("Execution Complete.")

# %%
# Print formatted timing metrics
print("==================================================")
print("             Pricing Engine Latencies             ")
print("==================================================")
print(f"Binomial Tree (100 steps) Warmup:      {perf['binomial_tree_warmup_ms']:.2f} ms")
print(f"Binomial Tree (100 steps) Steady State: {perf['binomial_tree_steady_us']:.2f} us")
print("--------------------------------------------------")
print(f"PDE Solver (101x100 grid) Warmup:      {perf['pde_warmup_ms']:.2f} ms")
print(f"PDE Solver (101x100 grid) Steady State: {perf['pde_steady_ms']:.2f} ms")
print("==================================================")
